# %% [markdown]
# <a href="https://colab.research.google.com/github/kaebmoo/example/blob/main/Individual_Work.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-46f3ba1e-7a40-46c2-9112-99d80bd96837" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-46f3ba1e-7a40-46c2-9112-99d80bd96837">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd


Credit_risk_data = pd.read_excel('Credit data.xlsx')

# %%
Credit_risk_data
# Out:
#       SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0                    1                              0.766127   45
# 1                    0                              0.957151   40
# 2                    0                              0.658180   38
# 3                    0                              0.233810   30
# 4                    0                              0.907239   49
# ...                ...                                   ...  ...
# 9995                 0                              0.629741   32
# 9996                 0                              0.062614   62
# 9997                 0                              0.827427   50
# 9998                 0                              0.091174   77
# 9999                 0                              0.000000   55
#
#       NumberOfTime30-59DaysPastDueNotWorse    DebtRatio  MonthlyIncome  \
# 0                                        2     0.802982         9120.0
# ...

# %%
Credit_risk_data.head()
# Out:
#    SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines  age  \
# 0                 1                              0.766127   45
# 1                 0                              0.957151   40
# 2                 0                              0.658180   38
# 3                 0                              0.233810   30
# 4                 0                              0.907239   49
#
#    NumberOfTime30-59DaysPastDueNotWorse  DebtRatio  MonthlyIncome  \
# 0                                     2   0.802982         9120.0
# 1                                     0   0.121876         2600.0
# 2                                     1   0.085113         3042.0
# 3                                     0   0.036050         3300.0
# 4                                     1   0.024926        63588.0
#
#    NumberOfOpenCreditLinesAndLoans  NumberOfTimes90DaysLate  \
# 0                               13                        0
# 1                                4                        0
# ...

# %%
Credit_risk_data.dtypes
# Out:
# SeriousDlqin2yrs                          int64
# RevolvingUtilizationOfUnsecuredLines    float64
# age                                       int64
# NumberOfTime30-59DaysPastDueNotWorse      int64
# DebtRatio                               float64
# MonthlyIncome                           float64
# NumberOfOpenCreditLinesAndLoans           int64
# NumberOfTimes90DaysLate                   int64
# NumberRealEstateLoansOrLines              int64
# NumberOfTime60-89DaysPastDueNotWorse      int64
# NumberOfDependents                      float64
# dtype: object

# %%
Credit_risk_data.describe()
# Out:
#        SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines           age  \
# count      10000.000000                          10000.000000  10000.000000
# mean           0.064000                              4.931206     52.164200
# std            0.244765                            160.479674     14.778792
# min            0.000000                              0.000000     21.000000
# 25%            0.000000                              0.031135     41.000000
# 50%            0.000000                              0.165328     52.000000
# 75%            0.000000                              0.571746     62.000000
# max            1.000000                           9340.000000    101.000000
#
#        NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  MonthlyIncome  \
# count                          10000.000000   10000.000000    8026.000000
# mean                               0.385100     350.457248    6606.379143
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
histograms = Credit_risk_data.hist()

# %% [markdown]
# NA Value

# %%
NA_count_by_column = Credit_risk_data.isnull().sum()
print("NA count by column:")
print(NA_count_by_column)
# Out:
# NA count by column:
# SeriousDlqin2yrs                           0
# RevolvingUtilizationOfUnsecuredLines       0
# age                                        0
# NumberOfTime30-59DaysPastDueNotWorse       0
# DebtRatio                                  0
# MonthlyIncome                           1974
# NumberOfOpenCreditLinesAndLoans            0
# NumberOfTimes90DaysLate                    0
# NumberRealEstateLoansOrLines               0
# NumberOfTime60-89DaysPastDueNotWorse       0
# NumberOfDependents                       284
# dtype: int64

# %% [markdown]
# #Cleaning Data
# 1. RevolvingUtilizationofunswcuredlines
# 2. DebtRatio
# #both of this cannot run

# %%
Credit_risk_data.describe()
# Out:
#        SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines           age  \
# count      10000.000000                          10000.000000  10000.000000
# mean           0.064000                              4.931206     52.164200
# std            0.244765                            160.479674     14.778792
# min            0.000000                              0.000000     21.000000
# 25%            0.000000                              0.031135     41.000000
# 50%            0.000000                              0.165328     52.000000
# 75%            0.000000                              0.571746     62.000000
# max            1.000000                           9340.000000    101.000000
#
#        NumberOfTime30-59DaysPastDueNotWorse      DebtRatio  MonthlyIncome  \
# count                          10000.000000   10000.000000    8026.000000
# mean                               0.385100     350.457248    6606.379143
# ...

# %%
import seaborn as sns
import numpy as np

# %%
sns.displot(Credit_risk_data['age'])

# %%
sns.displot(Credit_risk_data['NumberOfTime30-59DaysPastDueNotWorse'])

# %%
sns.displot(Credit_risk_data['NumberOfOpenCreditLinesAndLoans'])

# %%
sns.displot(Credit_risk_data['NumberOfTimes90DaysLate'])

# %%
sns.displot(Credit_risk_data['MonthlyIncome'])

# %%
sns.displot(Credit_risk_data['NumberRealEstateLoansOrLines'])

# %%
sns.displot(Credit_risk_data['NumberOfTime60-89DaysPastDueNotWorse'])

# %%
sns.displot(Credit_risk_data['NumberOfDependents'])
#่ห้ามกด run ใหม่เด็ดขาด!!!

# %%
sum(Credit_risk_data['NumberOfTime30-59DaysPastDueNotWorse'] >= 20)
# Out:
# 14

# %%
sum(Credit_risk_data['NumberOfTimes90DaysLate'] >= 20)
# Out:
# 14

# %%
sum(Credit_risk_data['NumberOfTime60-89DaysPastDueNotWorse'] >= 20)
# Out:
# 14

# %%
sum(Credit_risk_data['RevolvingUtilizationOfUnsecuredLines'] >= 1)
# Out:
# 194

# %%
Credit_risk_data=Credit_risk_data.drop(['MonthlyIncome'], axis=1)

# %%
# Fills out the null values with zeros. Inplace argument changes dataframe
Credit_risk_data['NumberOfDependents'].fillna(value = 0, inplace=True)
# Out:
# <ipython-input-25-a99347ea8242>:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   Credit_risk_data['NumberOfDependents'].fillna(value = 0, inplace=True)

# %%
sns.displot(Credit_risk_data['NumberOfDependents'])
#กราฟหลังแทน na = 0

# %%
Credit_risk_data = Credit_risk_data.loc[(Credit_risk_data['RevolvingUtilizationOfUnsecuredLines'] < 1) & (Credit_risk_data['NumberOfTime30-59DaysPastDueNotWorse'] < 8) & (Credit_risk_data['DebtRatio'] < 1) & (Credit_risk_data['NumberOfOpenCreditLinesAndLoans'] < 40)& (Credit_risk_data['NumberOfTimes90DaysLate'] < 8)& (Credit_risk_data['NumberRealEstateLoansOrLines'] < 10)& (Credit_risk_data['NumberOfTime60-89DaysPastDueNotWorse'] < 8)& (Credit_risk_data['NumberOfDependents'] < 5)]

# %%
sns.displot(Credit_risk_data['RevolvingUtilizationOfUnsecuredLines'])

# %%
sns.displot(Credit_risk_data['NumberOfTime30-59DaysPastDueNotWorse'])

# %%
sns.displot(Credit_risk_data['DebtRatio'])

# %%
sns.displot(Credit_risk_data['NumberOfOpenCreditLinesAndLoans'])

# %%
sns.displot(Credit_risk_data['NumberOfTimes90DaysLate'])

# %%
sns.displot(Credit_risk_data['NumberRealEstateLoansOrLines'])

# %%
sns.displot(Credit_risk_data['NumberOfTime60-89DaysPastDueNotWorse'])

# %%
sns.displot(Credit_risk_data['NumberOfDependents'])

# %% [markdown]
# #Weight of Evidence Transformation

# %%
pip install scorecardpy
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 kB 2.4 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for scorecardpy: filename=scorecardpy-0.1.9.7-py3-none-any.whl size=60629 sha256=2b71d96cc287435b78bf35bbace21ecae61dc416f3543c578afb5f078ae9fe60
#   Stored in directory: /root/.cache/pip/wheels/49/49/e9/7b845548eed3624ce37effdd13e9cb95a99272d692eb9e9e23
# Successfully built scorecardpy
# ...

# %% [markdown]
# #Binning

# %%
import scorecardpy as sc
import numpy as np

# %%
train, test = sc.split_df(Credit_risk_data,
                          y = 'SeriousDlqin2yrs',
                          ratio = 0.7, seed = 35976632).values()

# %%
train.describe()
# Out:
#        SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines          age  \
# count       5206.000000                           5206.000000  5206.000000
# mean           0.057242                              0.318149    51.698617
# std            0.232326                              0.340649    14.589511
# min            0.000000                              0.000000    21.000000
# 25%            0.000000                              0.032963    41.000000
# 50%            0.000000                              0.168416    51.000000
# 75%            0.000000                              0.548648    62.000000
# max            1.000000                              1.000000    98.000000
#
#        NumberOfTime30-59DaysPastDueNotWorse    DebtRatio  \
# count                           5206.000000  5206.000000
# mean                               0.239723     0.301469
# std                                0.677741     0.225192
# min                                0.000000     0.000000
# ...

# %%
bins = sc.woebin(train, y = 'SeriousDlqin2yrs',
                 min_perc_fine_bin=0.02, # How many bins to cut initially into
                 min_perc_coarse_bin=0.05,  # Minimum percentage per final bin
                 stop_limit=0.1, # Minimum information value
                 max_num_bin=8, # Maximum number of bins
                 method='tree')
# Out:
# [INFO] creating woe binning ...
# /usr/local/lib/python3.10/dist-packages/scorecardpy/condition_fun.py:40: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   datetime_cols = dat.apply(pd.to_numeric,errors='ignore').select_dtypes(object).apply(pd.to_datetime,errors='ignore').select_dtypes('datetime64').columns.tolist()
# /usr/local/lib/python3.10/dist-packages/scorecardpy/condition_fun.py:40: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   datetime_cols = dat.apply(pd.to_numeric,errors='ignore').select_dtypes(object).apply(pd.to_datetime,errors='ignore').select_dtypes('datetime64').columns.tolist()
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

sc.woebin_plot(bins)
# Out:
# {'NumberOfTime30-59DaysPastDueNotWorse': <Figure size 640x480 with 2 Axes>,
#  'NumberRealEstateLoansOrLines': <Figure size 640x480 with 2 Axes>,
#  'NumberOfTimes90DaysLate': <Figure size 640x480 with 2 Axes>,
#  'age': <Figure size 640x480 with 2 Axes>,
#  'NumberOfTime60-89DaysPastDueNotWorse': <Figure size 640x480 with 2 Axes>,
#  'DebtRatio': <Figure size 640x480 with 2 Axes>,
#  'RevolvingUtilizationOfUnsecuredLines': <Figure size 640x480 with 2 Axes>,
#  'NumberOfOpenCreditLinesAndLoans': <Figure size 640x480 with 2 Axes>,
#  'NumberOfDependents': <Figure size 640x480 with 2 Axes>}

# %%
breaks_adj = sc.woebin_adj(train, "SeriousDlqin2yrs", bins)
# Out:
# -------- 1/5 NumberOfDependents --------
# >>> dt[NumberOfDependents].describe():
# count    5206.000000
# mean        0.781598
# std         1.069234
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max         4.000000
# Name: NumberOfDependents, dtype: float64
#
# >>> dt[NumberOfDependents].value_counts():
# NumberOfDependents
# 0.0    2958
# 1.0    1023
# 2.0     743
# 3.0     368
# 4.0     114
# Name: count, dtype: int64
#
# >>> Current breaks:
# 1.0,3.0
# >>> Adjust breaks for (1/5) NumberOfDependents?
# 1: next
# 2: yes
# 3: back
# Selection: 1
# -------- 2/5 NumberOfOpenCreditLinesAndLoans --------
# >>> dt[NumberOfOpenCreditLinesAndLoans].describe():
# count    5206.000000
# mean        8.565309
# std         5.087086
# min         0.000000
# 25%         5.000000
# 50%         8.000000
# 75%        11.000000
# max        38.000000
# Name: NumberOfOpenCreditLinesAndLoans, dtype: float64
# >>> Current breaks:
# 4.0,6.0,13.0
# ...

# %%
breaks_adj = {
    'NumberRealEstateLoansOrLines': [1.0],
    'NumberOfDependents': [1.0],
    'DebtRatio': [0.02,0.44,0.56],
    'NumberOfOpenCreditLinesAndLoans': [4.0,6.0],}

# %%
bins_adj = sc.woebin(train, y="SeriousDlqin2yrs", breaks_list=breaks_adj)
sc.woebin_plot(bins_adj)
# Out:
# [INFO] creating woe binning ...
# /usr/local/lib/python3.10/dist-packages/scorecardpy/condition_fun.py:40: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_numeric without passing `errors` and catch exceptions explicitly instead
#   datetime_cols = dat.apply(pd.to_numeric,errors='ignore').select_dtypes(object).apply(pd.to_datetime,errors='ignore').select_dtypes('datetime64').columns.tolist()
# /usr/local/lib/python3.10/dist-packages/scorecardpy/condition_fun.py:40: FutureWarning: errors='ignore' is deprecated and will raise in a future version. Use to_datetime without passing `errors` and catch exceptions explicitly instead
#   datetime_cols = dat.apply(pd.to_numeric,errors='ignore').select_dtypes(object).apply(pd.to_datetime,errors='ignore').select_dtypes('datetime64').columns.tolist()
# ...

# %%
train_woe = sc.woebin_ply(train, bins_adj) # Calculate WoE dataset (train)
test_woe = sc.woebin_ply(test, bins_adj) # Calculate WoE dataset (test)
# Out:
# [INFO] converting into woe values ...
# [INFO] converting into woe values ...

# %%
train_woe.head()
# Out:
#    SeriousDlqin2yrs  NumberOfTime30-59DaysPastDueNotWorse_woe  \
# 0                 1                                  1.120311
# 2                 0                                  1.120311
# 3                 0                                 -0.414978
# 7                 0                                 -0.414978
# 9                 0                                 -0.414978
#
#    NumberRealEstateLoansOrLines_woe  NumberOfTimes90DaysLate_woe   age_woe  \
# 0                         -0.211276                    -0.337776  0.180384
# 2                          0.276616                     2.169342  0.180384
# 3                          0.276616                    -0.337776  0.629713
# 7                          0.276616                    -0.337776  0.180384
# 9                         -0.211276                    -0.337776 -0.351646
#
#    NumberOfTime60-89DaysPastDueNotWorse_woe  DebtRatio_woe  \
# 0                                       0.0       0.560819
# ...

# %% [markdown]
# IV Filtering
# Now we can check the information value of our variables and remove those who are not predictive. We use the function iv. In general:
#
# 𝐼𝑉<0.02 : No predictive ability, remove.
# 0.02≤𝐼𝑉<0.1 : Small predictive ability, suggest to remove.
# 0.1≤𝐼𝑉<0.3 : Medium predictive ability, leave.
# 0.3≤𝐼𝑉<1 : Good predictive ability, leave.
# 1≤𝐼𝑉 : Strong predictive ability. Suspicious variable. Study if error in calculation (i.e. WoE leaves a category with 100% goods or bads) or if variable is capturing future information.

# %%
sc.iv(train_woe, 'SeriousDlqin2yrs')
# Out:
#                                    variable  info_value
# 7  RevolvingUtilizationOfUnsecuredLines_woe    0.823259
# 6               NumberOfTimes90DaysLate_woe    0.693029
# 2  NumberOfTime30-59DaysPastDueNotWorse_woe    0.447825
# 4                                   age_woe    0.268659
# 1                             DebtRatio_woe    0.080468
# 3       NumberOfOpenCreditLinesAndLoans_woe    0.065726
# 8          NumberRealEstateLoansOrLines_woe    0.058159
# 0                    NumberOfDependents_woe    0.032687
# 5  NumberOfTime60-89DaysPastDueNotWorse_woe    0.000000

# %%
# Check column order.
train_woe.columns
# Out:
# Index(['SeriousDlqin2yrs', 'NumberOfTime30-59DaysPastDueNotWorse_woe',
#        'NumberRealEstateLoansOrLines_woe', 'NumberOfTimes90DaysLate_woe',
#        'age_woe', 'NumberOfTime60-89DaysPastDueNotWorse_woe', 'DebtRatio_woe',
#        'RevolvingUtilizationOfUnsecuredLines_woe',
#        'NumberOfOpenCreditLinesAndLoans_woe', 'NumberOfDependents_woe'],
#       dtype='object')

# %%
# Create range of accepted variables
train_woe_adj = train_woe.drop(['NumberOfOpenCreditLinesAndLoans_woe','NumberRealEstateLoansOrLines_woe','NumberOfDependents_woe','NumberOfTime60-89DaysPastDueNotWorse_woe'],axis=1)
test_woe_adj = test_woe.drop(['NumberOfOpenCreditLinesAndLoans_woe','NumberRealEstateLoansOrLines_woe','NumberOfDependents_woe','NumberOfTime60-89DaysPastDueNotWorse_woe'],axis=1)
train_woe_adj.head()
# Out:
#    SeriousDlqin2yrs  NumberOfTime30-59DaysPastDueNotWorse_woe  \
# 0                 1                                  1.120311
# 2                 0                                  1.120311
# 3                 0                                 -0.414978
# 7                 0                                 -0.414978
# 9                 0                                 -0.414978
#
#    NumberOfTimes90DaysLate_woe   age_woe  DebtRatio_woe  \
# 0                    -0.337776  0.180384       0.560819
# 2                     2.169342  0.180384      -0.154149
# 3                    -0.337776  0.629713      -0.154149
# 7                    -0.337776  0.180384      -0.154149
# 9                    -0.337776 -0.351646       0.560819
#
#    RevolvingUtilizationOfUnsecuredLines_woe
# 0                                  1.010620
# 2                                  1.010620
# 3                                 -1.003826
# 7                                  1.010620
# ...

# %%
test_woe_adj.head()
# Out:
#     SeriousDlqin2yrs  NumberOfTime30-59DaysPastDueNotWorse_woe  \
# 1                  0                                 -0.414978
# 4                  0                                  1.120311
# 5                  0                                 -0.414978
# 12                 0                                 -0.414978
# 13                 1                                  1.120311
#
#     NumberOfTimes90DaysLate_woe   age_woe  DebtRatio_woe  \
# 1                     -0.337776  0.180384      -0.154149
# 4                     -0.337776  0.180384      -0.154149
# 5                     -0.337776 -0.760599      -0.154149
# 12                    -0.337776  0.180384      -0.154149
# 13                     2.169342  0.180384      -0.154149
#
#     RevolvingUtilizationOfUnsecuredLines_woe
# 1                                   1.010620
# 4                                   1.010620
# 5                                  -1.003826
# 12                                 -1.003826
# ...

# %%
train_woe.describe()
# Out:
#        SeriousDlqin2yrs  NumberOfTime30-59DaysPastDueNotWorse_woe  \
# count       5206.000000                               5206.000000
# mean           0.057242                                 -0.172564
# std            0.232326                                  0.559885
# min            0.000000                                 -0.414978
# 25%            0.000000                                 -0.414978
# 50%            0.000000                                 -0.414978
# 75%            0.000000                                 -0.414978
# max            1.000000                                  1.120311
#
#        NumberRealEstateLoansOrLines_woe  NumberOfTimes90DaysLate_woe  \
# count                       5206.000000                  5206.000000
# mean                          -0.025435                    -0.208712
# std                            0.236948                     0.554058
# min                           -0.211276                    -0.337776
# ...

# %% [markdown]
# #Generating a logistic regression object

# %%
from sklearn.linear_model import LogisticRegression #couldnt use l1 lasso like the example

Credit_risk_data_logreg = LogisticRegression(penalty='l2', # Type of penalization l1 = lasso, l2 = ridge
                                     tol=0.0001, # Tolerance for parameters
                                     C=1.0, # Penalty constant, see below
                                     fit_intercept=True, # Use constant?
                                     class_weight='balanced', # Weights, see below
                                     random_state=35976632, # Random seed
                                     max_iter=100, # Maximum iterations
                                     verbose=1, # Show process. 1 is yes.
                                     solver = 'saga',
                                     warm_start=False # Train anew or start from previous weights. For repeated training.
                                    )

# %% [markdown]
# #Training

# %%
Credit_risk_data_logreg.fit(X = train_woe.iloc[:,1:], # All rows and from the second var to end
                    y = train_woe['SeriousDlqin2yrs'] # The target
                   )
# Out:
# convergence after 34 epochs took 0 seconds
# LogisticRegression(class_weight='balanced', random_state=35976632,
#                    solver='saga', verbose=1)

# %%
coef_df = pd.concat([pd.DataFrame({'column': train_woe.columns[1:]}),
                    pd.DataFrame(np.transpose(Credit_risk_data_logreg.coef_))],
                    axis = 1
                   )
coef_df
# Out:
#                                      column         0
# 0  NumberOfTime30-59DaysPastDueNotWorse_woe  0.673540
# 1          NumberRealEstateLoansOrLines_woe  0.455295
# 2               NumberOfTimes90DaysLate_woe  0.755951
# 3                                   age_woe  0.711455
# 4  NumberOfTime60-89DaysPastDueNotWorse_woe  0.000000
# 5                             DebtRatio_woe  0.976819
# 6  RevolvingUtilizationOfUnsecuredLines_woe  0.642909
# 7       NumberOfOpenCreditLinesAndLoans_woe  0.230195
# 8                    NumberOfDependents_woe  0.015168

# %%
Credit_risk_data_logreg.intercept_
# Out:
# array([0.00440616])

# %% [markdown]
# #Applying to the test set

# %%
pred_class_test = Credit_risk_data_logreg.predict(test_woe.iloc[:, 1:])
probs_test = Credit_risk_data_logreg.predict_proba(test_woe.iloc[:, 1:])
print(probs_test, pred_class_test)
# Out:
# [[0.44027966 0.55972034]
#  [0.26974631 0.73025369]
#  [0.86309402 0.13690598]
#  ...
#  [0.57290037 0.42709963]
#  [0.57290037 0.42709963]
#  [0.79047194 0.20952806]] [1 1 0 ... 0 0 0]

# %%
from sklearn.metrics import roc_auc_score, confusion_matrix

# %%
confusion_matrix(y_true = test_woe['SeriousDlqin2yrs'], y_pred = pred_class_test)
# Out:
# array([[1605,  498],
#        [  38,   90]])

# %%
roc_auc_score(y_true = test_woe['SeriousDlqin2yrs'], y_score = probs_test[:,1])
# Out:
# 0.8073306734427009

# %%
from sklearn.metrics import roc_curve
import matplotlib.pyplot as plt
# %matplotlib inline

# Calculate the ROC curve points
fpr, tpr, thresholds = roc_curve(test_woe['SeriousDlqin2yrs'], probs_test[:,1])

# Save the AUC in a variable to display it. Round it first
auc = np.round(roc_auc_score(y_true = test_woe['SeriousDlqin2yrs'],
                             y_score = probs_test[:,1]),
              decimals = 3)

# Create and show the plot
plt.plot(fpr,tpr,label="Credit risk, auc="+str(auc))
plt.legend(loc=4)
plt.show()

# %% [markdown]
# #Scorecard

# %%
Credit_risk_sc = sc.scorecard(bins_adj, Credit_risk_data_logreg,
             train_woe.columns[1:], # The column names in the trained LR
             points0=600, # Base points
             odds0=0.01, # Base odds
             pdo=50) # PDO

# %%
Credit_risk_sc
# Out:
# {'basepoints':      variable  bin  points
#  0  basepoints  NaN   267.0,
#  'NumberOfTime30-59DaysPastDueNotWorse':                                variable         bin  points
#  0  NumberOfTime30-59DaysPastDueNotWorse  [-inf,1.0)    20.0
#  1  NumberOfTime30-59DaysPastDueNotWorse   [1.0,inf)   -54.0,
#  'NumberRealEstateLoansOrLines':                        variable         bin  points
#  2  NumberRealEstateLoansOrLines  [-inf,1.0)    -9.0
#  3  NumberRealEstateLoansOrLines   [1.0,inf)     7.0,
#  'NumberOfTimes90DaysLate':                   variable         bin  points
#  4  NumberOfTimes90DaysLate  [-inf,1.0)    18.0
#  5  NumberOfTimes90DaysLate   [1.0,inf)  -118.0,
#  'age':    variable          bin  points
#  6       age  [-inf,34.0)   -32.0
#  7       age  [34.0,56.0)    -9.0
#  8       age  [56.0,64.0)    18.0
#  9       age  [64.0,76.0)    39.0
#  10      age   [76.0,inf)    98.0,
#  'DebtRatio':      variable          bin  points
#  12  DebtRatio  [-inf,0.02)    19.0
# ...

# %%
# Applying the credit score. Applies over the original data!
train_score = sc.scorecard_ply(train, Credit_risk_sc,
                               print_step=0)
test_score = sc.scorecard_ply(test, Credit_risk_sc,
                               print_step=0)
# Out:
# /usr/local/lib/python3.10/dist-packages/scorecardpy/scorecard.py:353: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat_score.loc[:,'score'] = card_basepoints + dat_score.sum(axis=1)
# /usr/local/lib/python3.10/dist-packages/scorecardpy/scorecard.py:353: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dat_score.loc[:,'score'] = card_basepoints + dat_score.sum(axis=1)

# %%
train_score.describe()
# Out:
#              score
# count  5206.000000
# mean    314.460430
# std      86.337792
# min     -14.000000
# 25%     266.000000
# 50%     333.000000
# 75%     365.000000
# max     479.000000

# %% [markdown]
# #Random Forests

# %%
from sklearn.ensemble import RandomForestClassifier
Credit_risk_data_rf = RandomForestClassifier(n_estimators=1000, # Number of trees to train
                       criterion='gini', # How to train the trees. Also supports entropy.
                       max_depth=None, # Max depth of the trees. Not necessary to change.
                       min_samples_split=2, # Minimum samples to create a split.
                       min_samples_leaf=0.001, # Minimum samples in a leaf. Accepts fractions for %. This is 0.1% of sample.
                       min_weight_fraction_leaf=0.0, # Same as above, but uses the class weights.
                       max_features='log2', # Maximum number of features per split (not tree!) by default is sqrt(vars)
                       max_leaf_nodes=None, # Maximum number of nodes.
                       min_impurity_decrease=0.0001, # Minimum impurity decrease. This is 10^-3.
                       bootstrap=True, # If sample with repetition. For large samples (>100.000) set to false.
                       oob_score=True,  # If report accuracy with non-selected cases.
                       n_jobs=-1, # Parallel processing. Set to -1 for all cores. Watch your RAM!!
                       random_state=35976632, # Seed
                       verbose=1, # If to give info during training. Set to 0 for silent training.
                       warm_start=False, # If train over previously trained tree.
                       class_weight='balanced'
                                    )

# %%
train.describe()
# Out:
#        SeriousDlqin2yrs  RevolvingUtilizationOfUnsecuredLines          age  \
# count       5206.000000                           5206.000000  5206.000000
# mean           0.057242                              0.318149    51.698617
# std            0.232326                              0.340649    14.589511
# min            0.000000                              0.000000    21.000000
# 25%            0.000000                              0.032963    41.000000
# 50%            0.000000                              0.168416    51.000000
# 75%            0.000000                              0.548648    62.000000
# max            1.000000                              1.000000    98.000000
#
#        NumberOfTime30-59DaysPastDueNotWorse    DebtRatio  \
# count                           5206.000000  5206.000000
# mean                               0.239723     0.301469
# std                                0.677741     0.225192
# min                                0.000000     0.000000
# ...

# %%
Credit_risk_data_rf.fit(train.iloc[:,1:],
               train['SeriousDlqin2yrs'])
# Out:
# [Parallel(n_jobs=-1)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=-1)]: Done  46 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=-1)]: Done 196 tasks      | elapsed:    2.0s
# [Parallel(n_jobs=-1)]: Done 446 tasks      | elapsed:    4.0s
# [Parallel(n_jobs=-1)]: Done 796 tasks      | elapsed:    6.0s
# [Parallel(n_jobs=-1)]: Done 1000 out of 1000 | elapsed:    7.1s finished
# RandomForestClassifier(class_weight='balanced', max_features='log2',
#                        min_impurity_decrease=0.0001, min_samples_leaf=0.001,
#                        n_estimators=1000, n_jobs=-1, oob_score=True,
#                        random_state=35976632, verbose=1)

# %%
from sklearn.metrics import roc_auc_score, confusion_matrix, roc_curve

# Apply the model to the test set.
rf_pred_class_test = Credit_risk_data_rf.predict(test.iloc[:, 1:])
rf_probs_test = Credit_risk_data_rf.predict_proba(test.iloc[:, 1:])
# Out:
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  46 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done 196 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 446 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 796 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=2)]: Done 1000 out of 1000 | elapsed:    0.6s finished
# [Parallel(n_jobs=2)]: Using backend ThreadingBackend with 2 concurrent workers.
# [Parallel(n_jobs=2)]: Done  46 tasks      | elapsed:    0.0s
# [Parallel(n_jobs=2)]: Done 196 tasks      | elapsed:    0.1s
# [Parallel(n_jobs=2)]: Done 446 tasks      | elapsed:    0.3s
# [Parallel(n_jobs=2)]: Done 796 tasks      | elapsed:    0.5s
# [Parallel(n_jobs=2)]: Done 1000 out of 1000 | elapsed:    0.6s finished

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

# Calculate confusion matrix
confusion_matrix_rf = confusion_matrix(y_true = test['SeriousDlqin2yrs'],
                    y_pred = rf_pred_class_test)

# Turn matrix to percentages
confusion_matrix_rf = confusion_matrix_rf.astype('float') / confusion_matrix_rf.sum(axis=1)[:, np.newaxis]

# Turn to dataframe
df_cm = pd.DataFrame(
        confusion_matrix_rf, index=['good', 'bad'], columns=['good', 'bad'],
)

# Parameters of the image
figsize = (10,7)
fontsize=14

# Create image
fig = plt.figure(figsize=figsize)
heatmap = sns.heatmap(df_cm, annot=True, fmt='.2f')

# Make it nicer
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0,
                             ha='right', fontsize=fontsize)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45,
                             ha='right', fontsize=fontsize)

# Add labels
plt.ylabel('True label')
plt.xlabel('Predicted label')

# Plot!
plt.show()

# %%
# Calculate the ROC curve points
fpr, tpr, thresholds = roc_curve(test['SeriousDlqin2yrs'], rf_probs_test[:,1])

# Save the AUC in a variable to display it. Round it first
auc = np.round(roc_auc_score(y_true = test['SeriousDlqin2yrs'],
                             y_score = rf_probs_test[:,1]),
              decimals = 3)

# Create and show the plot
plt.plot(fpr,tpr,label="Credit_risk RF, auc="+str(auc))
plt.legend(loc=4)
plt.show()

# %%
for name, importance in zip(train.columns[1:], Credit_risk_data_rf.feature_importances_):
  print(name, "= %.2f" % importance)
# Out:
# RevolvingUtilizationOfUnsecuredLines = 0.30
# age = 0.15
# NumberOfTime30-59DaysPastDueNotWorse = 0.08
# DebtRatio = 0.15
# NumberOfOpenCreditLinesAndLoans = 0.09
# NumberOfTimes90DaysLate = 0.10
# NumberRealEstateLoansOrLines = 0.04
# NumberOfTime60-89DaysPastDueNotWorse = 0.06
# NumberOfDependents = 0.04

# %% [markdown]
# #XGBoosting

# %%
from sklearn.ensemble import GradientBoostingClassifier

Credit_risk_data_xg = GradientBoostingClassifier(loss='log_loss', # How to calculate losses. Deviance is for probabilistic outputs. Alternative exponential for AdaBoost.
                           learning_rate=0.1, # How much to shrink error in each subsequent training. Trade-off with no. estimators.
                           n_estimators=100, # How many trees to use, the more the better, but decrease learning rate if many used.
                           subsample=0.632, # Subsampling to use. 63.2% of data is standard for XGBoost.
                           criterion='friedman_mse', # Error to use for each split. Good idea to leave it as is.
                           min_samples_split=2, # Minimum samples for a split.
                           min_samples_leaf=1, # Minimum samples in a leaf.
                           min_weight_fraction_leaf=0.0, # Minimum fraction of samples in a leaf. Consider increasing if first few trees too good.
                           max_depth=3, # Maximum depth. Keep it small!
                           min_impurity_decrease=0.01, # Minimum impurity decrease. Might want to use 1% or so.
                           init=None, # How to make first prediction (it needs one). Can give model that supports fit and predict.
                           random_state=35976632, # Seed
                           max_features='log2', # Same as RF.
                           verbose=1,  # Same as RF.
                           max_leaf_nodes=None,  # Same as RF.
                           warm_start=False,  # Same as RF.
                           #presort='auto', # Whether to presort the data to speed up training.
                           validation_fraction=0.3, # XGBoost CAN overfit, so control this just in case. Uses 30% validation in this case.
                           n_iter_no_change=None, # Iters to stop training if no change occurs between one tree and the next.
                           tol=0.0001 # Tolerance. Means maximum change of 10^-4
                          )

# %%
Credit_risk_data_xg.fit(train.iloc[:,1:],
                train['SeriousDlqin2yrs'])
# Out:
#       Iter       Train Loss      OOB Improve   Remaining Time
#          1           0.3851           0.0278            1.47s
#          2           0.4238           0.1074            1.09s
#          3           0.3913          -0.0258            0.96s
#          4           0.4010           0.0395            0.87s
#          5           0.3751          -0.0280            0.88s
#          6           0.3388          -0.0460            0.81s
#          7           0.3483           0.0300            0.77s
#          8           0.3597           0.0304            0.78s
#          9           0.3494          -0.0069            0.76s
#         10           0.3574           0.0173            0.75s
#         20           0.3353           0.0101            0.62s
#         30           0.3160          -0.0157            0.52s
#         40           0.3236           0.0216            0.43s
#         50           0.3040          -0.0300            0.35s
# ...

# %%
# Apply the model to the test set.
xg_pred_class_test = Credit_risk_data_xg.predict(test.iloc[:, 1:])
xg_probs_test = Credit_risk_data_xg.predict_proba(test.iloc[:, 1:])

# %%
# Calculate confusion matrix
confusion_matrix_xg = confusion_matrix(y_true = test['SeriousDlqin2yrs'],
                    y_pred = xg_pred_class_test)

# Turn matrix to percentages
confusion_matrix_xg = confusion_matrix_xg.astype('float') / confusion_matrix_xg.sum(axis=1)[:, np.newaxis]

# Turn to dataframe
df_cm = pd.DataFrame(
        confusion_matrix_xg, index=['good', 'bad'], columns=['good', 'bad'],
)

# Parameters of the image
figsize = (10,7)
fontsize=14

# Create image
fig = plt.figure(figsize=figsize)
heatmap = sns.heatmap(df_cm, annot=True, fmt='.2f')

# Make it nicer
heatmap.yaxis.set_ticklabels(heatmap.yaxis.get_ticklabels(), rotation=0,
                             ha='right', fontsize=fontsize)
heatmap.xaxis.set_ticklabels(heatmap.xaxis.get_ticklabels(), rotation=45,
                             ha='right', fontsize=fontsize)

# Add labels
plt.ylabel('True label')
plt.xlabel('Predicted label')

# Plot!
plt.show()

# %%
# Calculate the ROC curve points
fpr, tpr, thresholds = roc_curve(test['SeriousDlqin2yrs'], xg_probs_test[:,1])

# Save the AUC in a variable to display it. Round it first
auc = np.round(roc_auc_score(y_true = test['SeriousDlqin2yrs'],
                             y_score = xg_probs_test[:,1]),
              decimals = 3)

# Create and show the plot
plt.plot(fpr,tpr,label="Credit risk XG, auc="+str(auc))
plt.legend(loc=4)
plt.show()

# %% [markdown]
# #Comparison

# %%
# Predict probabilities of scorecard.
logreg_probs_test = Credit_risk_data_logreg.predict_proba(test_woe.iloc[:, 1:])

# %%
# Set models and probabilities. This structure is called a dictionary.
models = [
{
    'label': 'Logistic Regression',
    'probs': logreg_probs_test[:,1]
},
{
    'label': 'Gradient Boosting',
    'probs': xg_probs_test[:,1]
},
{
    'label': 'Random Forest',
    'probs': rf_probs_test[:,1]
}
]

# Loop that creates the plot. I will pass each ROC curve one by one.
for m in models:
  auc = roc_auc_score(y_true = test['SeriousDlqin2yrs'],
                             y_score = m['probs'])
  fpr, tpr, thresholds = roc_curve(test['SeriousDlqin2yrs'],
                                           m['probs'])
  plt.plot(fpr, tpr, label='%s ROC (area = %0.3f)' % (m['label'], auc))



# Settings
plt.plot([0, 1], [0, 1],'r--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('1-Specificity(False Positive Rate)')
plt.ylabel('Sensitivity(True Positive Rate)')
plt.title('Receiver Operating Characteristic')
plt.legend(loc="lower right")

# Plot!
plt.show()
